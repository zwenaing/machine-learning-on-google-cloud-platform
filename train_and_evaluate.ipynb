# %%
# %bash
git clone https://github.com/GoogleCloudPlatform/training-data-analyst
# Out:
# fatal: destination path 'training-data-analyst' already exists and is not an empty directory.

# %%
import tensorflow as tf
import numpy as np

# %%
path = 'training-data-analyst/courses/machine_learning/deepdive/03_tensorflow/'

CSV_COLUMNS = ['fare_amount', 'pickuplon','pickuplat','dropofflon','dropofflat','passengers', 'key']
LABEL_COLUMN = 'fare_amount'
DEFAULTS = [[0.0], [-74.0], [40.0], [-74.0], [40.7], [1.0], ['nokey']]

def read_dataset(filename, mode, batch_size = 512):
  def _input_fn():
    def decode_csv(value_column):
      columns = tf.decode_csv(value_column, record_defaults = DEFAULTS)
      features = dict(zip(CSV_COLUMNS, columns))
      label = features.pop(LABEL_COLUMN)
      return features, label

    # Create list of file names that match "glob" pattern (i.e. data_file_*.csv)
    filenames_dataset = tf.data.Dataset.list_files(filename)
    # Read lines from text files
    textlines_dataset = filenames_dataset.flat_map(tf.data.TextLineDataset)
    # Parse text lines as comma-separated values (CSV)
    dataset = textlines_dataset.map(decode_csv)
    
    # Note:
    # use tf.data.Dataset.flat_map to apply one to many transformations (here: filename -> text lines)
    # use tf.data.Dataset.map      to apply one to one  transformations (here: text line -> feature list)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        num_epochs = None # indefinitely
        dataset = dataset.shuffle(buffer_size = 10 * batch_size)
    else:
        num_epochs = 1 # end-of-input after this

    dataset = dataset.repeat(num_epochs).batch(batch_size)
    
    return dataset.make_one_shot_iterator().get_next()
  return _input_fn
    

def get_train():
  return read_dataset(path + 'taxi-train.csv', mode = tf.estimator.ModeKeys.TRAIN)

def get_valid():
  return read_dataset(path + 'taxi-valid.csv', mode = tf.estimator.ModeKeys.EVAL)

def get_test():
  return read_dataset(path + 'taxi-test.csv', mode = tf.estimator.ModeKeys.EVAL)

# %%
feature_columns = [tf.feature_column.numeric_column(f) for f in CSV_COLUMNS[1:len(CSV_COLUMNS) - 1]]

# %%
def serving_input_fn():
#   feature_placeholders = dict(zip(CSV_COLUMNS[1:len(CSV_COLUMNS) - 1], [tf.placeholder(tf.float32, [None])] * len(CSV_COLUMNS) - 2))
  feature_placeholders = {
    'pickuplon' : tf.placeholder(tf.float32, [None]),
    'pickuplat' : tf.placeholder(tf.float32, [None]),
    'dropofflat' : tf.placeholder(tf.float32, [None]),
    'dropofflon' : tf.placeholder(tf.float32, [None]),
    'passengers' : tf.placeholder(tf.float32, [None]),
  }
  features = feature_placeholders
  return tf.estimator.export.ServingInputReceiver(features, feature_placeholders)

# %%
import shutil

log_dir = 'taxi-trained'

shutil.rmtree(log_dir, ignore_errors=True)

model = tf.estimator.LinearRegressor(
  feature_columns=feature_columns,
  model_dir=log_dir
)

train_spec = tf.estimator.TrainSpec(
  input_fn=get_train(),
  max_steps=2000
)

exporter = tf.estimator.LatestExporter(
  name='exporter',
  serving_input_receiver_fn=serving_input_fn
)

eval_spec = tf.estimator.EvalSpec(
  input_fn=get_valid(),
  steps=300,
  exporters=exporter,
  start_delay_secs=20,
  throttle_secs=10
)

tf.estimator.train_and_evaluate(model, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1227 into taxi-trained/model.ckpt.
# INFO:tensorflow:loss = 45958.676, step = 1227
# INFO:tensorflow:global_step/sec: 36.2716
# INFO:tensorflow:loss = 48847.508, step = 1327 (2.766 sec)
# INFO:tensorflow:global_step/sec: 34.1486
# INFO:tensorflow:loss = 42454.203, step = 1427 (2.927 sec)
# INFO:tensorflow:global_step/sec: 38.912
# INFO:tensorflow:loss = 37684.086, step = 1527 (2.571 sec)
# INFO:tensorflow:Saving checkpoints for 1545 into taxi-trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 32336.557.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-15:20:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-1545
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-11-15:20:50
# INFO:tensorflow:Saving dict for global step 1545: average_loss = 109.61288, global_step = 1545, loss = 45626.36
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'passengers': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'pickuplon': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'dropofflon': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=float32>, 'pickuplat': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'dropofflat': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'passengers': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'pickuplon': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'dropofflon': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=float32>, 'pickuplat': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'dropofflat': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-1545
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: taxi-trained/export/exporter/temp-1528730450/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-1545
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1546 into taxi-trained/model.ckpt.
# INFO:tensorflow:loss = 48467.867, step = 1546
# INFO:tensorflow:global_step/sec: 37.1121
# INFO:tensorflow:loss = 45096.31, step = 1646 (2.700 sec)
# INFO:tensorflow:global_step/sec: 35.8948
# INFO:tensorflow:loss = 37359.74, step = 1746 (2.787 sec)
# INFO:tensorflow:global_step/sec: 40.2149
# INFO:tensorflow:loss = 53690.227, step = 1846 (2.489 sec)
# INFO:tensorflow:Saving checkpoints for 1880 into taxi-trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 41214.992.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-15:21:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-1880
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-11-15:21:01
# INFO:tensorflow:Saving dict for global step 1880: average_loss = 109.16615, global_step = 1880, loss = 45440.41
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'passengers': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'pickuplon': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'dropofflon': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=float32>, 'pickuplat': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'dropofflat': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'passengers': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'pickuplon': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'dropofflon': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=float32>, 'pickuplat': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'dropofflat': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-1880
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: taxi-trained/export/exporter/temp-1528730461/saved_model.pb
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-1880
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1881 into taxi-trained/model.ckpt.
# INFO:tensorflow:loss = 47955.586, step = 1881
# INFO:tensorflow:global_step/sec: 37.554
# INFO:tensorflow:loss = 42748.17, step = 1981 (2.670 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into taxi-trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 42522.2.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-11-15:21:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-11-15:21:06
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 109.01161, global_step = 2000, loss = 45376.082
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'passengers': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'pickuplon': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'dropofflon': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=float32>, 'pickuplat': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'dropofflat': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'passengers': <tf.Tensor 'Placeholder_4:0' shape=(?,) dtype=float32>, 'pickuplon': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=float32>, 'dropofflon': <tf.Tensor 'Placeholder_3:0' shape=(?,) dtype=float32>, 'pickuplat': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=float32>, 'dropofflat': <tf.Tensor 'Placeholder_2:0' shape=(?,) dtype=float32>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from taxi-trained/model.ckpt-2000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: taxi-trained/export/exporter/temp-1528730467/saved_model.pb

# %%
from google.datalab.ml import TensorBoard

# %%
TensorBoard().start(log_dir)
# Out:
# OSErrorTraceback (most recent call last)
# <ipython-input-45-e96945380f73> in <module>()
# ----> 1 shutil.rmtree(log_dir)
#       2
#       3 TensorBoard().start(log_dir)
#
# /usr/local/envs/py2env/lib/python2.7/shutil.pyc in rmtree(path, ignore_errors, onerror)
#     251         names = os.listdir(path)
#     252     except os.error, err:
# --> 253         onerror(os.listdir, path, sys.exc_info())
#     254     for name in names:
#     255         fullname = os.path.join(path, name)
#
# /usr/local/envs/py2env/lib/python2.7/shutil.pyc in rmtree(path, ignore_errors, onerror)
#     249     names = []
#     250     try:
# --> 251         names = os.listdir(path)
#     252     except os.error, err:
#     253         onerror(os.listdir, path, sys.exc_info())
#
# OSError: [Errno 2] No such file or directory: 'taxi-trained'

# %%
# TensorBoard().stop(8333)
TensorBoard().list()
# Out:
#          logdir    pid   port
# 0  taxi-trained  17003  38211

# %%
# %bash
ls
# Out:
# README.md
# taxi-trained
# train_and_evaluate.ipynb
# training-data-analyst
